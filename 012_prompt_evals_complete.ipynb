# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-haiku-4-5"

# %%
# Helper functions
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)


def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)


def chat(messages, system=None, temperature=1.0, stop_sequences=[]):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message.content[0].text

# %%
# Function to generate a new dataset
import json


def generate_dataset():
    prompt = """
Generate a evaluation dataset for a prompt evaluation. The dataset will be used to evaluate prompts
that generate Python, JSON, or Regex specifically for AWS-related tasks. Generate an array of JSON objects,
each representing task that requires Python, JSON, or a Regex to complete.

Example output:
```json
[
    {
        "task": "Description of task",
        "format": "json" or "python" or "regex",
        "solution_criteria": "Key criteria for evaluating the solution."
    },
    ...additional
]
```

* Focus on tasks that can be solved by writing a single Python function, a single JSON object, or a regular expression.
* Focus on tasks that do not require writing much code

Please generate 3 objects.
"""

    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```json")
    text = chat(messages, stop_sequences=["```"])
    return json.loads(text)

# %%
# Generate the dataset and write it to 'dataset.json'
dataset = generate_dataset()
with open("dataset.json", "w") as f:
    json.dump(dataset, f, indent=2)

# %%
# Function to grade a test case + output using a model
def grade_by_model(test_case, output):
    eval_prompt = f"""
You are an expert AWS code reviewer. Your task is to evaluate the following AI-generated solution.

Original Task:
<task>
{test_case["task"]}
</task>

Solution to Evaluate:
<solution>
{output}
</solution>

Criteria you should use to evaluate the solution:
<criteria>
{test_case["solution_criteria"]}
</criteria>

Output Format
Provide your evaluation as a structured JSON object with the following fields, in this specific order:
- "strengths": An array of 1-3 key strengths
- "weaknesses": An array of 1-3 key areas for improvement
- "reasoning": A concise explanation of your overall assessment
- "score": A number between 1-10

Respond with JSON. Keep your response concise and direct.
Example response shape:
{{
    "strengths": string[],
    "weaknesses": string[],
    "reasoning": string,
    "score": number
}}
    """

    messages = []
    add_user_message(messages, eval_prompt)
    add_assistant_message(messages, "```json")
    eval_text = chat(messages, stop_sequences=["```"])
    return json.loads(eval_text)

# %%
# Passes a test case into Claude
def run_prompt(test_case):
    prompt = f"""
Please solve the following task:

{test_case["task"]}

* Respond only with Python, JSON, or a plain Regex
* Do not add any comments or commentary or explanation
"""

    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```code")
    output = chat(messages, stop_sequences=["```"])
    return output

# %%
# Functions to validate the output structure
import re
import ast


def validate_json(text):
    try:
        json.loads(text.strip())
        return 10
    except json.JSONDecodeError:
        return 0


def validate_python(text):
    try:
        ast.parse(text.strip())
        return 10
    except SyntaxError:
        return 0


def validate_regex(text):
    try:
        re.compile(text.strip())
        return 10
    except re.error:
        return 0


def grade_syntax(response, test_case):
    format = test_case["format"]
    if format == "json":
        return validate_json(response)
    elif format == "python":
        return validate_python(response)
    else:
        return validate_regex(response)

# %%
# Function to execute a single test case and grade the output
def run_test_case(test_case):
    """Calls run_prompt, then grades the result"""
    output = run_prompt(test_case)

    model_grade = grade_by_model(test_case, output)
    model_score = model_grade["score"]
    reasoning = model_grade["reasoning"]

    syntax_score = grade_syntax(output, test_case)

    score = (model_score + syntax_score) / 2

    return {
        "output": output,
        "test_case": test_case,
        "score": score,
        "reasoning": reasoning,
    }

# %%
from statistics import mean


def run_eval(dataset):
    """Loads the dataset and calls run_test_case with each case"""
    results = []

    for test_case in dataset:
        result = run_test_case(test_case)
        results.append(result)

    average_score = mean([result["score"] for result in results])
    print(f"Average score: {average_score}")

    return results

# %%
with open("dataset.json", "r") as f:
    dataset = json.load(f)

results = run_eval(dataset)
# Out:
# Average score: 7.666666666666667

# %%
print(json.dumps(results, indent=2))
# Out:
# [
#   {
#     "output": "\nimport json\nimport re\nimport sys\n\ndef extract_resource_ids_json(template_str):\n    \"\"\"Extract resource logical IDs from CloudFormation template using JSON parsing\"\"\"\n    try:\n        template = json.loads(template_str)\n        if isinstance(template, dict) and \"Resources\" in template:\n            return list(template[\"Resources\"].keys())\n        return []\n    except json.JSONDecodeError:\n        return []\n\ndef extract_resource_ids_regex(template_str):\n    \"\"\"Extract resource logical IDs using regex as fallback\"\"\"\n    pattern = r'\"Resources\"\\s*:\\s*\\{([^}]*?)(?=\"[A-Za-z_][A-Za-z0-9_]*\"\\s*:)'\n    matches = re.findall(r'\"([A-Za-z_][A-Za-z0-9_]*)\"\\s*:\\s*\\{[^}]*?\"Type\"\\s*:', template_str)\n    return matches\n\ndef extract_resource_ids(template_str):\n    \"\"\"Main function to extract resource logical IDs\"\"\"\n    ids = extract_resource_ids_json(template_str)\n    if not ids:\n        ids = extract_resource_ids_regex(template_str)\n    return ids\n\nif __name__ == \"__main__\":\n    if len(sys.argv) > 1:\n        with open(sys.argv[1], 'r') as f:\n            template = f.read()\n    else:\n        template = sys.stdin.read()\n    \n    resource_ids = extract_resource_ids(template)\n    print(json.dumps(resource_ids, indent=2))\n",
#     "test_case": {
#       "task": "Parse an AWS CloudFormation template and extract all resource logical IDs",
#       "format": "python",
#       "solution_criteria": "Function should take a CloudFormation JSON/YAML template as input and return a list of all logical resource IDs. Should handle both JSON and YAML formats."
#     },
#     "score": 7.0,
#     "reasoning": "The solution addresses the JSON portion of the task adequately through standard JSON parsing, but fundamentally fails to meet the stated requirement of handling both JSON AND YAML formats. The regex fallback, while well-intentioned, is unreliable and doesn't solve the YAML problem. To properly support YAML, the solution needs to import and use a YAML parser library (e.g., PyYAML). The lack of YAML support is a critical gap that makes this solution incomplete for real-world CloudFormation templates, where YAML is widely used."
#   },
#   {
#     "output": "\n{\n  \"Version\": \"2012-10-17\",\n  \"Statement\": [\n    {\n      \"Effect\": \"Allow\",\n      \"Action\": [\n        \"s3:GetObject\",\n        \"s3:GetObjectVersion\",\n        \"s3:ListBucket\",\n        \"s3:GetBucketVersioning\",\n        \"s3:GetBucketLocation\",\n        \"s3:ListAllMyBuckets\"\n      ],\n      \"Resource\": [\n        \"arn:aws:s3:::*\",\n        \"arn:aws:s3:::*/*\"\n      ]\n    }\n  ]\n}\n",
#     "test_case": {
#       "task": "Create an AWS IAM policy JSON that allows read-only access to all S3 buckets",
#       "format": "json",
#       "solution_criteria": "Valid IAM policy document with appropriate S3 read-only actions (s3:GetObject, s3:ListBucket) for all resources. Must follow AWS policy syntax."
#     },
#     "score": 9.0,
#     "reasoning": "The policy is fundamentally sound and meets the core requirement of read-only S3 access across all buckets with valid syntax and appropriate action selections. The resource ARNs properly target both bucket and object levels. However, the inclusion of ListAllMyBuckets with wildcard resources is slightly unconventional (typically given its own statement), and some edge-case read permissions are omitted. These are minor issues that don't break functionality but represent room for optimization and completeness."
#   },
#   {
#     "output": "\n^arn:aws[a-z\\-]*:[a-z0-9\\-]*:[a-z0-9\\-]*:[0-9]{12}:[a-z0-9/_\\-:.]*$\n",
#     "test_case": {
#       "task": "Write a regex pattern to validate AWS ARN (Amazon Resource Name) format",
#       "format": "regex",
#       "solution_criteria": "Pattern should match valid ARNs (e.g., arn:aws:s3:::bucket-name) and reject invalid formats. Should handle common AWS services like EC2, S3, IAM, and RDS."
#     },
#     "score": 7.0,
#     "reasoning": "The pattern captures the general ARN structure but has critical failures with real-world AWS ARNs. Most notably, it rejects valid S3 ARNs which have empty account IDs. The regex lacks flexibility for optional fields and doesn't enforce service-specific naming conventions. While it's a reasonable starting point, it would reject legitimate AWS resources."
#   }
# ]
